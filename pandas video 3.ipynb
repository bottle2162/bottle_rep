# %%
import pandas as pd

# %%
pdf = pd.read_excel("E:/titanic.xlsx")

# %%
pdf
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
pdf.loc[pdf["sex"]=="male"]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
mani=pdf.head(30)

# %%
mani
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
mani.drop([4,5],inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10600\3106586348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mani.drop([4,5],inplace=True)

# %%
mani.head(10)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# ...

# %%
mani.drop(3)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# 11         1       1  female  58.0      0      0   26.5500        S   First
# 12         0       3    male  20.0      0      0    8.0500        S   Third
# 13         0       3    male  39.0      1      5   31.2750        S   Third
# ...

# %%
mani.drop(["class","fare"],axis=1,inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10600\2616157843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mani.drop(["class","fare"],axis=1,inplace=True)

# %%
mani
# Out:
#     survived  pclass     sex   age  sibsp  parch embarked    who  adult_male  \
# 0          0       3    male  22.0      1      0        S    man        True
# 1          1       1  female  38.0      1      0        C  woman       False
# 2          1       3  female  26.0      0      0        S  woman       False
# 3          1       1  female  35.0      1      0        S  woman       False
# 6          0       1    male  54.0      0      0        S    man        True
# 7          0       3    male   2.0      3      1        S  child       False
# 8          1       3  female  27.0      0      2        S  woman       False
# 9          1       2  female  14.0      1      0        C  child       False
# 10         1       3  female   4.0      1      1        S  child       False
# 11         1       1  female  58.0      0      0        S  woman       False
# 12         0       3    male  20.0      0      0        S    man        True
# ...

# %%
pdf.drop_duplicates(keep="first",inplace=True)

# %%
pdf
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
pdf.duplicated().sum()
# Out:
# 0

# %%
pdf.iloc[[2,3,4],[2,3,4]]
# Out:
#       sex   age  sibsp
# 2  female  26.0      0
# 3  female  35.0      1
# 4    male  35.0      0

# %%
pdd=pd.read_excel("E:/tips.xlsx")

# %%
pdd
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
round(pdd.tip.mean(),5)
# Out:
# 2.99828

# %%
pdd.sort_values("total_bill",ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..          ...    ...     ...    ...   ...     ...   ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]

# %%
pdf.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
pdf["alone"]
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 885    False
# 887     True
# 888    False
# 889     True
# 890     True
# Name: alone, Length: 784, dtype: bool

# %%
pdf.sort_values(["embark_town","age"],ascending=[True,False])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 96          0       1    male  71.0      0      0  34.6542        C  First
# 493         0       1    male  71.0      0      0  49.5042        C  First
# 54          0       1    male  65.0      0      1  61.9792        C  First
# 366         1       1  female  60.0      1      0  75.2500        C  First
# 587         1       1    male  60.0      1      1  79.2000        C  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 826         0       3    male   NaN      0      0  56.4958        S  Third
# 868         0       3    male   NaN      0      0   9.5000        S  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 829         1       1  female  62.0      0      0  80.0000      NaN  First
# 61          1       1  female  38.0      0      0  80.0000      NaN  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
pdf.duplicated().sum()
# Out:
# 0

# %%
user=pd.DataFrame({"mani":[11,23,45],"maniii":[11,22,33]})

# %%
user
# Out:
#    mani  maniii
# 0    11      11
# 1    23      22
# 2    45      33

# %%
users=pd.DataFrame({"mani":[11,23,45],"maniii":[11,22,33]})

# %%
users
# Out:
#    mani  maniii
# 0    11      11
# 1    23      22
# 2    45      33

# %%
pd.concat([user,users],axis=1)
# Out:
#    mani  maniii  mani  maniii
# 0    11      11    11      11
# 1    23      22    23      22
# 2    45      33    45      33

# %%
sales=pd.read_csv("C:/Users/user/Desktop/toys/sales.csv")

# %%
prds=pd.read_csv("C:/Users/user/Desktop/toys/products.csv")

# %%
store=pd.read_csv("C:/Users/user/Desktop/toys/stores.csv")

# %%
store.pivot(index="Store_Open_Date",columns="Store_Name")
# Out:
#                                    Store_ID                        \
# Store_Name      Maven Toys Aguascalientes 1 Maven Toys Campeche 1
# Store_Open_Date
# 1992-09-18                              NaN                   NaN
# 1995-04-27                              NaN                   NaN
# 1999-12-27                              NaN                   NaN
# 2000-01-01                              NaN                   NaN
# 2001-05-31                              NaN                   NaN
# 2003-12-13                              NaN                   NaN
# 2003-12-25                              NaN                   NaN
# 2004-10-14                              NaN                   NaN
# 2004-10-15                              NaN                   NaN
# 2005-01-14                              NaN                  10.0
# 2005-04-19                              NaN                   NaN
# 2006-05-05                              NaN                   NaN
# ...

# %%
store
# Out:
#     Store_ID                     Store_Name        Store_City Store_Location  \
# 0          1       Maven Toys Guadalajara 1       Guadalajara    Residential
# 1          2         Maven Toys Monterrey 1         Monterrey    Residential
# 2          3       Maven Toys Guadalajara 2       Guadalajara     Commercial
# 3          4          Maven Toys Saltillo 1          Saltillo       Downtown
# 4          5            Maven Toys La Paz 1            La Paz       Downtown
# 5          6          Maven Toys Mexicali 1          Mexicali     Commercial
# 6          7         Maven Toys Monterrey 2         Monterrey       Downtown
# 7          8           Maven Toys Pachuca 1           Pachuca       Downtown
# 8          9  Maven Toys Ciudad de Mexico 1  Cuidad de Mexico       Downtown
# 9         10          Maven Toys Campeche 1          Campeche       Downtown
# 10        11        Maven Toys Cuernavaca 1        Cuernavaca       Downtown
# ...

# %%
sales
# Out:
#         Sale_ID        Date  Store_ID  Product_ID  Units
# 0             1  2022-01-01        24           4      1
# 1             2  2022-01-01        28           1      1
# 2             3  2022-01-01         6           8      1
# 3             4  2022-01-01        48           7      1
# 4             5  2022-01-01        44          18      1
# ...         ...         ...       ...         ...    ...
# 829257   829258  2023-09-30        24          19      1
# 829258   829259  2023-09-30        16          35      1
# 829259   829260  2023-09-30        22          19      1
# 829260   829261  2023-09-30        13           2      2
# 829261   829262  2023-09-30        32           6      1
#
# [829262 rows x 5 columns]

# %%
prds.head()
# Out:
#    Product_ID      Product_Name Product_Category Product_Cost Product_Price
# 0           1     Action Figure             Toys       $9.99        $15.99
# 1           2    Animal Figures             Toys       $9.99        $12.99
# 2           3   Barrel O' Slime     Art & Crafts       $1.99         $3.99
# 3           4  Chutes & Ladders            Games       $9.99        $12.99
# 4           5  Classic Dominoes            Games       $7.99         $9.99

# %%
prds.pivot(index="Product_Category",columns="Product_Name",values="Product_Cost")
# Out:
# Product_Name      Action Figure Animal Figures Barrel O' Slime  \
# Product_Category
# Art & Crafts                NaN            NaN          $1.99
# Electronics                 NaN            NaN             NaN
# Games                       NaN            NaN             NaN
# Sports & Outdoors           NaN            NaN             NaN
# Toys                     $9.99          $9.99              NaN
#
# Product_Name      Chutes & Ladders Classic Dominoes Colorbuds Dart Gun  \
# Product_Category
# Art & Crafts                   NaN              NaN       NaN      NaN
# Electronics                    NaN              NaN    $6.99       NaN
# Games                       $9.99            $7.99        NaN      NaN
# Sports & Outdoors              NaN              NaN       NaN  $11.99
# Toys                           NaN              NaN       NaN      NaN
#
# Product_Name      Deck Of Cards Dino Egg Dinosaur Figures  ...  \
# ...

# %%
main=sales.merge(prds,on="Product_ID") #innerjoin

# %%
main.sort_values(["Product_ID"],ascending=True)
# Out:
#         Sale_ID        Date  Store_ID  Product_ID  Units   Product_Name  \
# 38522    502872  2023-02-28        25           1      1  Action Figure
# 34792    414251  2022-12-28        50           1      1  Action Figure
# 34793    414326  2022-12-28        21           1      1  Action Figure
# 34794    414362  2022-12-28         7           1      1  Action Figure
# 34795    414385  2022-12-28         1           1      1  Action Figure
# ...         ...         ...       ...         ...    ...            ...
# 369637   576773  2023-04-15        18          35      1  Uno Card Game
# 369636   576745  2023-04-15        18          35      1  Uno Card Game
# 369635   576578  2023-04-15        18          35      1  Uno Card Game
# 369653   580364  2023-04-18         7          35      1  Uno Card Game
# 367908       28  2022-01-01        10          35      1  Uno Card Game
#
#        Product_Category Product_Cost Product_Price
# 38522              Toys       $9.99        $15.99
# ...

# %%
main1=main.merge(store,on="Store_ID",how="outer")

# %%
main1.duplicated().sum()
# Out:
# 0

# %%
main1.drop_duplicates(keep="first")
# Out:
#         Sale_ID        Date  Store_ID  Product_ID  Units      Product_Name  \
# 0             1  2022-01-01        24           4      1  Chutes & Ladders
# 1            66  2022-01-01        24           4      1  Chutes & Ladders
# 2            98  2022-01-01        24           4      1  Chutes & Ladders
# 3           128  2022-01-01        24           4      1  Chutes & Ladders
# 4           146  2022-01-01        24           4      1  Chutes & Ladders
# ...         ...         ...       ...         ...    ...               ...
# 829257   793189  2023-09-04        13          28      1          Playfoam
# 829258   820255  2023-09-25        13          28      1          Playfoam
# 829259   820290  2023-09-25        13          28      1          Playfoam
# 829260   820877  2023-09-25        13          28      1          Playfoam
# 829261   821027  2023-09-25        13          28      1          Playfoam
#
#        Product_Category Product_Cost Product_Price  \
# ...

# %%
import numpy as np

# %%
main["Product_ID"][main["Product_ID"].isin(prds["Product_ID"])]
# Out:
# 0          4
# 1          4
# 2          4
# 3          4
# 4          4
#           ..
# 829257    28
# 829258    28
# 829259    28
# 829260    28
# 829261    28
# Name: Product_ID, Length: 829262, dtype: int64

# %%
np.all(main["Product_ID"].isin(prds["Product_ID"]))
# Out:
# True

# %%
mm=main1.head()

# %%
mm
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1  2022-01-01        24           4      1  Chutes & Ladders
# 1       66  2022-01-01        24           4      1  Chutes & Ladders
# 2       98  2022-01-01        24           4      1  Chutes & Ladders
# 3      128  2022-01-01        24           4      1  Chutes & Ladders
# 4      146  2022-01-01        24           4      1  Chutes & Ladders
#
#   Product_Category Product_Cost Product_Price                   Store_Name  \
# 0            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 1            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 2            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 3            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 4            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
#
#        Store_City Store_Location Store_Open_Date
# ...

# %%
main1.groupby("Product_Category")["Product_Price"].max()
# Out:
# Product_Category
# Art & Crafts          $4.99
# Electronics          $25.99
# Games                 $9.99
# Sports & Outdoors     $9.99
# Toys                  $9.99
# Name: Product_Price, dtype: object

# %%
pdf.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
pdf.groupby("class")["fare"].aggregate(["min","max"])
# Out:
#         min       max
# class
# First   0.0  512.3292
# Second  0.0   73.5000
# Third   0.0   69.5500

# %%
tips=pd.read_excel("E:/tips.xlsx")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
mnmn=tips.groupby("day")["tip"].aggregate(["min","max"]).reset_index()

# %%
mnmn
# Out:
#     day   min    max
# 0   Fri  1.00   4.73
# 1   Sat  1.00  10.00
# 2   Sun  1.01   6.50
# 3  Thur  1.25   6.70

# %%
mnmn.loc[mnmn["max"]>5,"day"]
# Out:
# 1     Sat
# 2     Sun
# 3    Thur
# Name: day, dtype: object

# %%
len(mnmn)
# Out:
# 4

# %%
np.all(tips["day"].isin(mnmn))
# Out:
# False

# %%
tips.loc[tips["day"].isin(mnmn)]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
jj= tips.groupby("day")[["total_bill","sex"]].aggregate({"total_bill":["min","max"],"sex":"count"})

# %%
jj.reset_index(inplace=True)

# %%
jj.columns
# Out:
# MultiIndex([(       'day',      ''),
#             ('total_bill',   'min'),
#             ('total_bill',   'max'),
#             (       'sex', 'count')],
#            )

# %%
[i**2 for i in range(10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
jj.columns=["_".join(i) for i in jj.columns]

# %%
jj
# Out:
#    day_  total_bill_min  total_bill_max  sex_count
# 0   Fri            5.75           40.17         19
# 1   Sat            3.07           50.81         87
# 2   Sun            7.25           48.17         76
# 3  Thur            7.51           43.11         62

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
main1.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1  2022-01-01        24           4      1  Chutes & Ladders
# 1       66  2022-01-01        24           4      1  Chutes & Ladders
# 2       98  2022-01-01        24           4      1  Chutes & Ladders
# 3      128  2022-01-01        24           4      1  Chutes & Ladders
# 4      146  2022-01-01        24           4      1  Chutes & Ladders
#
#   Product_Category Product_Cost Product_Price                   Store_Name  \
# 0            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 1            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 2            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 3            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 4            Games       $9.99        $12.99   Maven Toys Aguascalientes 1
#
#        Store_City Store_Location Store_Open_Date
# ...

# %%
main1.pivot(index="Store_ID",columns="Date")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 main1.pivot(index="Store_ID",columns="Date")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9025, in DataFrame.pivot(self, columns, index, values)
#    9018 @Substitution("")
#    9019 @Appender(_shared_docs["pivot"])
#    9020 def pivot(
#    9021     self, *, columns, index=lib.no_default, values=lib.no_default
#    9022 ) -> DataFrame:
#    9023     from pandas.core.reshape.pivot import pivot
# -> 9025     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:553, in pivot(data, columns, index, values)
#     549         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     550 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
# ...
